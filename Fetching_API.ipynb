# %% [markdown]
# <a href="https://colab.research.google.com/github/rayan239/100_days_ML/blob/main/Fetching_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/upcoming?api_key=33588ac5c03c374776f99c62e44ec4b7")

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#          id                            title  \
# 0   1078605                          Weapons
# 1   1242011                         Together
# 2    604079                    The Long Walk
# 3    980477                         Ne Zha 2
# 4   1071585                        M3GAN 2.0
# 5   1149504                     Honey Don't!
# 6   1241470                           Osiris
# 7   1088166                            Relay
# 8   1419406                The Shadow's Edge
# 9   1197306                    A Working Man
# 10  1289936  Downton Abbey: The Grand Finale
# 11  1054867         One Battle After Another
# 12  1285965                Dangerous Animals
# 13    76600         Avatar: The Way of Water
# 14  1241921     A Big Bold Beautiful Journey
# 15      557                       Spider-Man
# 16  1319969                           Sketch
# 17      105               Back to the Future
# 18      559                     Spider-Man 3
# 19  1245993                  Caught Stealing
#
# ...

# %%
for i in range(1,62):
    response = requests.get("https://api.themoviedb.org/3/movie/upcoming?api_key=33588ac5c03c374776f99c62e44ec4b7&page={}".format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#            id                   title  \
# 0     1078605                 Weapons
# 1     1242011                Together
# 2      604079           The Long Walk
# 3      980477                Ne Zha 2
# 4     1071585               M3GAN 2.0
# ...       ...                     ...
# 1212  1480737              Sore Thumb
# 1213  1468599      Halloween Vacation
# 1214  1190422               The Knock
# 1215  1133411  I'll Come Back for You
# 1216  1133411  I'll Come Back for You
#
#                                                overview release_date  \
# 0     When all but one child from the same class mys...   2025-08-04
# 1     With a move to the countryside already testing...   2025-07-28
# 2     In a dystopian, alternate-America ruled by a t...   2025-09-10
# 3     After a catastrophic event leaves their bodies...   2025-01-29
# 4     After the underlying tech for M3GAN is stolen ...   2025-06-25
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (1217, 7)

# %%
df.to_csv('movie.csv')
